# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import cv2
import json
# Out:
# WARNING:tensorflow:From C:\Users\US593\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ##### matching image with deepface

# %%
img1 = cv2.imread('rdj1.jpeg')
plt.imshow(img1)

# %%
img2 = cv2.imread('rdj2.jpeg')
plt.imshow(img2)

# %%
results = DeepFace.verify(img1_path = 'rdj1.jpeg',img2_path = 'rdj2.jpeg')

# %%
results
# Out:
# {'verified': True,
#  'distance': 0.38363714847820374,
#  'threshold': 0.4,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 57, 'y': 41, 'w': 132, 'h': 132},
#   'img2': {'x': 16, 'y': 81, 'w': 137, 'h': 137}},
#  'time': 7.76}

# %%
img3 = cv2.imread('notrdj.jpeg')
plt.imshow(img3)

# %%
results = DeepFace.verify(img1_path = 'rdj1.jpeg',img2_path = 'notrdj.jpeg')

# %%
results
# Out:
# {'verified': False,
#  'distance': 0.48597982144378027,
#  'threshold': 0.4,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 57, 'y': 41, 'w': 132, 'h': 132},
#   'img2': {'x': 31, 'y': 58, 'w': 138, 'h': 138}},
#  'time': 1.55}

# %% [markdown]
# ##### finding image in database with deepface

# %%
results = DeepFace.find(img_path='rdj1.jpeg',db_path = r'C:\Users\US593\OneDrive\Desktop\project\database')
# Out:
# Finding representations: 100%|███████████████████████████████████████████████████████████| 6/6 [00:06<00:00,  1.07s/it]
# 24-02-03 00:27:50 - Representations stored in C:\Users\US593\OneDrive\Desktop\project\database/representations_vgg_face.pkl file.Please delete this file when you add new identities in your database.
# 24-02-03 00:27:51 - find function lasts 7.557850122451782 seconds

# %%
results
# Out:
# [                                            identity  target_x  target_y  \
#  0  C:\Users\US593\OneDrive\Desktop\project\databa...       125       110
#  1  C:\Users\US593\OneDrive\Desktop\project\databa...        80       163
#
#     target_w  target_h  source_x  source_y  source_w  source_h  VGG-Face_cosine
#  0       253       253        57        41       132       132         0.265168
#  1       551       551        57        41       132       132         0.290844  ]

# %%
type(results)
# Out:
# list

# %%
results[0]
# Out:
#                                             identity  target_x  target_y  \
# 0  C:\Users\US593\OneDrive\Desktop\project\databa...       125       110
# 1  C:\Users\US593\OneDrive\Desktop\project\databa...        80       163
#
#    target_w  target_h  source_x  source_y  source_w  source_h  VGG-Face_cosine
# 0       253       253        57        41       132       132         0.265168
# 1       551       551        57        41       132       132         0.290844

# %%
img = cv2.imread(results[0].iloc[0,0])

# %%
plt.imshow(img)

# %%
img = cv2.imread(results[0].iloc[1,0])

# %%
plt.imshow(img)

# %% [markdown]
# ##### analyzing image with deepface

# %%
results = DeepFace.analyze(img_path = 'rdj1.jpeg')
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.22it/s]

# %%
results
# Out:
# [{'emotion': {'angry': 57.09830862869672,
#    'disgust': 0.0010566012581379436,
#    'fear': 1.7288244428530004,
#    'happy': 0.004291974875085421,
#    'sad': 38.26025356413445,
#    'surprise': 0.0010395298596691908,
#    'neutral': 2.9062246773376867},
#   'dominant_emotion': 'angry',
#   'region': {'x': 57, 'y': 41, 'w': 132, 'h': 132},
#   'face_confidence': 7.446198083111085,
#   'age': 34,
#   'gender': {'Woman': 0.0031073570426087826, 'Man': 99.99688863754272},
#   'dominant_gender': 'Man',
#   'race': {'asian': 3.0718363789818515,
#    'indian': 5.195413839543691,
#    'black': 0.723091136922904,
#    'white': 8.702219796313035,
#    'middle eastern': 3.7661614278651134,
#    'latino hispanic': 78.5412775600718},
#   'dominant_race': 'latino hispanic'}]
